# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from parser import parse

# Parse data
data = parse('data_stab.txt')

# Convert time to relative seconds
t0 = data['t'][0] if data['t'] else 0
time_s = [(t - t0) / 1e6 for t in data['t']]

# Create subplots
fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
                    subplot_titles=('Magnetic Field vs Time', 'Current vs Time'))

# Magnetic field
for key in ['bx', 'by', 'bz']:
    fig.add_trace(go.Scatter(x=time_s, y=data[key], name=key), row=1, col=1)

# Currents
for key in ['ux', 'i1']:
    fig.add_trace(go.Scatter(x=time_s, y=data[key], name=key), row=2, col=1)

fig.update_yaxes(title_text='Magnetic Field', row=1, col=1)
fig.update_yaxes(title_text='Current', row=2, col=1)
fig.update_xaxes(title_text='Time (s)', row=2, col=1)

fig.update_layout(height=800)
fig.show()

# %%
# Parse data
data = parse('data_step.txt')

# Convert time to relative seconds
t0 = data['t'][0] if data['t'] else 0
t0 = 14193822
time_s = [(t - t0) / 1e6 for t in data['t']]

# Create subplots
fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
                    subplot_titles=('Commanded Current vs Time', 'Current vs Time'))

# Commanded current
for key in ['ux']:
    fig.add_trace(go.Scatter(x=time_s, y=data[key], name="i1_cmd"), row=1, col=1)

# Currents
for key in ['i1']:
    fig.add_trace(go.Scatter(x=time_s, y=data[key], name="i1 PWM=18310.55Hz"), row=2, col=1)

# Parse data
data = parse('data_step2.txt')

# Convert time to relative seconds
t0 = data['t'][0] if data['t'] else 0
t0 = 13887821
time_s = [(t - t0) / 1e6 for t in data['t']]

# Commanded current
for key in ['ux']:
    fig.add_trace(go.Scatter(x=time_s, y=data[key], name="i1_cmd"), row=1, col=1)

# Currents
for key in ['i1']:
    fig.add_trace(go.Scatter(x=time_s, y=data[key], name="i1 PWM=36621.09Hz"), row=2, col=1)

fig.update_yaxes(title_text='Commanded Current', row=1, col=1)
fig.update_yaxes(title_text='Current', row=2, col=1)
fig.update_xaxes(title_text='Time (s)', row=2, col=1)

fig.update_layout(height=800)
fig.show()
